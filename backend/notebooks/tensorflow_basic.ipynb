# %% [markdown]
# # TensorFlow 基础示例
# 本 notebook 演示 TensorFlow 基本用法。

# %%
import tensorflow as tf
print('TensorFlow 版本:', tf.__version__)

# %%
import numpy as np
a = np.array([1, 2, 3])
print('numpy 数组:', a)
